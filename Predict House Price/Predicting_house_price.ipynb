# %%
import pandas as pd
import numpy as np
import random

# %%
data=pd.read_csv("C:/Users/88018/Downloads/Housing.csv")

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
coder=LabelEncoder()

# %%
columns=['mainroad','guestroom','basement','hotwaterheating','airconditioning','prefarea','furnishingstatus']

# %%
for i in columns:
    data[i]=coder.fit_transform(data[i])

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
X=data.iloc[:,1:]

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
Y=data.iloc[:,0]
Y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test=train_test_split(X,Y,test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
Y_pred
# Out:
# array([ 3222697.48313944,  4793882.77335687,  2362835.92284903,
#         3155852.78129965,  6292360.15854358,  4022564.4862588 ,
#         3706433.95671892,  3045306.91066344,  3998475.25171116,
#         3256035.84967503,  3671539.04018631,  3260756.84936568,
#         3693301.76806877,  5101075.47163118,  4875473.25002394,
#         6819716.45813992,  7283270.22991689,  4604820.88726469,
#         2921011.82989114,  4356873.45038024,  5571526.89372581,
#         4756288.00333779,  4815041.19788237,  6389680.65587042,
#         2124548.60773897,  2719809.32812724,  2705155.0275766 ,
#         4285444.18958954,  4862212.18454519,  3359205.42802302,
#         5071984.94417488,  4065421.09971589,  3847615.10417126,
#         4758451.78292223,  4065099.26199085,  7451686.83861347,
#         2492421.47427414,  5187428.05893814,  4899642.43346759,
#         2707507.79489226,  6846404.97349076,  3290602.67621792,
#         3486437.86975117,  4196957.25802276,  3072077.14325658,
# ...

# %%
from sklearn import metrics

# %%
R2_Score=metrics.r2_score(Y_test,Y_pred)
R2_Score
# Out:
# 0.6509413309763019

# %%
MSE=metrics.mean_squared_error(Y_test,Y_pred)
MSE
# Out:
# 1282938497147.5095

# %%
rSquared_error= 1-R2_Score
rSquared_error
# Out:
# 0.3490586690236981

# %%
MAE=metrics.mean_absolute_error(Y_test,Y_pred)
MAE
# Out:
# 836107.255122822

# %%
model.coef_
# Out:
# array([ 2.33615015e+02,  7.69490651e+04,  9.80317148e+05,  4.24397178e+05,
#         3.16621453e+05,  3.42008910e+05,  4.04773543e+05,  8.23662015e+05,
#         9.26098618e+05,  2.84987932e+05,  6.52951423e+05, -2.59155828e+05])

# %%
model.intercept_
# Out:
# 404428.1134765353
